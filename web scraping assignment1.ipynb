# %%
pip install bs4
# Out:
# ...
#
# ...

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.mehar.com/india/jeans"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 6]>
# <html id="ie6" class="ie" lang="en-US">
# <![endif]-->
# <!--[if IE 7]>
# <html id="ie7" class="ie" lang="en-US">
# <![endif]-->
# <!--[if IE 8]>
# <html id="ie8" class="ie" lang="en-US">
# <![endif]-->
# <!--[if IE 9]>
# <html id="ie9" class="ie" lang="en-US">
# <![endif]-->
# <!--[if !(IE 6) | !(IE 7) | !(IE 8) | !(IE 9) ]><!-->
# <html lang="en">
# <head>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=yes" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="#0087be" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="j9jDypyUF0xMApY7i7dIwVXiDbtJzw9YwrNE6DKs" name="csrf-token"/>
# <meta content="https://www.mehar.com/images/mehar.jpg" property="og:image">
# <meta content="https://www.mehar.com/images/mehar.jpg" property="og:image:secure_url">
# <meta content="800" property="og:image:width">
# <meta content="620" property="og:image:height"/>
# ...

# %%
name=soup.select(".product-titile")

# %%
name
# Out:
# [<h2 class="product-titile">
#                                          Greenish Grey Straight Fit Men's Jeans
#                                         </h2>,
#  <h2 class="product-titile">
#                                          Grey Wide Leg Men's Ultra Fashion Jeans
#                                         </h2>,
#  <h2 class="product-titile">
#                                          Blue Wide Leg Men's Ultra Fashion Jeans
#                                         </h2>,
#  <h2 class="product-titile">
#                                          Black Straight Fit Raw Wash Men's Fashion Jeans
#                                         </h2>,
#  <h2 class="product-titile">
#                                          Blue and Black Two Tone Wide Leg Men's Fashion Jeans
#                                         </h2>,
#  <h2 class="product-titile">
#                                          Green Wide Leg Men's Fashion Jeans
#                                         </h2>,
# ...

# %%
ratings=soup.select("#listingReviewBtn .d-inline-block")

# %%
ratings
# Out:
# [<span class="star-rating-system d-inline-block">
#  <span class="rating-5"></span>
#  </span>,
#  <span class="star-rating-system d-inline-block">
#  <span class="rating-5"></span>
#  </span>,
#  <span class="star-rating-system d-inline-block">
#  <span class="rating-5"></span>
#  </span>,
#  <span class="star-rating-system d-inline-block">
#  <span class="rating-5"></span>
#  </span>,
#  <span class="star-rating-system d-inline-block">
#  <span class="rating-5"></span>
#  </span>,
#  <span class="star-rating-system d-inline-block">
#  <span class="rating-4"></span>
#  </span>,
#  <span class="star-rating-system d-inline-block">
#  <span class="rating-4"></span>
#  </span>,
#  <span class="star-rating-system d-inline-block">
#  <span class="rating-5"></span>
#  </span>,
#  <span class="star-rating-system d-inline-block">
#  <span class="rating-5"></span>
#  </span>,
#  <span class="star-rating-system d-inline-block">
#  <span class="rating-5"></span>
#  </span>,
# ...

# %%
price=soup.select("#listing-products strong")

# %%
price
# Out:
# [<strong>₹2299</strong>,
#  <strong>₹2449</strong>,
#  <strong>₹2799</strong>,
#  <strong>₹2099</strong>,
#  <strong>₹2299</strong>,
#  <strong>₹2099</strong>,
#  <strong>₹2099</strong>,
#  <strong>₹2099</strong>,
#  <strong>₹2099</strong>,
#  <strong>₹2199</strong>,
#  <strong>₹2099</strong>,
#  <strong>₹2099</strong>,
#  <strong>₹1699</strong>,
#  <strong>₹1999</strong>,
#  <strong>₹2099</strong>,
#  <strong>₹2299</strong>,
#  <strong>₹1999</strong>,
#  <strong>₹2199</strong>]

# %%
discount=soup.select(".product-offers-new")

# %%
discount
# Out:
# [<span class="product-offers-new">54% OFF</span>,
#  <span class="product-offers-new">51% OFF</span>,
#  <span class="product-offers-new">44% OFF</span>,
#  <span class="product-offers-new">48% OFF</span>,
#  <span class="product-offers-new">54% OFF</span>,
#  <span class="product-offers-new">48% OFF</span>,
#  <span class="product-offers-new">40% OFF</span>,
#  <span class="product-offers-new">40% OFF</span>,
#  <span class="product-offers-new">58% OFF</span>,
#  <span class="product-offers-new">45% OFF</span>,
#  <span class="product-offers-new">40% OFF</span>,
#  <span class="product-offers-new">58% OFF</span>,
#  <span class="product-offers-new">59% OFF</span>,
#  <span class="product-offers-new">50% OFF</span>,
#  <span class="product-offers-new">58% OFF</span>,
#  <span class="product-offers-new">34% OFF</span>,
#  <span class="product-offers-new">43% OFF</span>,
#  <span class="product-offers-new">37% OFF</span>]

# %%
import pandas

# %%
name
# Out:
# [<h2 class="product-titile">
#                                          Greenish Grey Straight Fit Men's Jeans
#                                         </h2>,
#  <h2 class="product-titile">
#                                          Grey Wide Leg Men's Ultra Fashion Jeans
#                                         </h2>,
#  <h2 class="product-titile">
#                                          Blue Wide Leg Men's Ultra Fashion Jeans
#                                         </h2>,
#  <h2 class="product-titile">
#                                          Black Straight Fit Raw Wash Men's Fashion Jeans
#                                         </h2>,
#  <h2 class="product-titile">
#                                          Blue and Black Two Tone Wide Leg Men's Fashion Jeans
#                                         </h2>,
#  <h2 class="product-titile">
#                                          Green Wide Leg Men's Fashion Jeans
#                                         </h2>,
# ...

# %%
pant=pandas.DataFrame(name,columns=['pant name'])

# %%
pant
# Out:
#                                             pant name
# 0   \n                                        Gree...
# 1   \n                                        Grey...
# 2   \n                                        Blue...
# 3   \n                                        Blac...
# 4   \n                                        Blue...
# 5   \n                                        Gree...
# 6   \n                                        Midn...
# 7   \n                                        Blac...
# 8   \n                                        Ligh...
# 9   \n                                        Beav...
# 10  \n                                        Blac...
# 11  \n                                        Purp...
# 12  \n                                        Rhys...
# 13  \n                                        Cool...
# 14  \n                                        Blac...
# 15  \n                                        Blac...
# ...

# %%
pant["ratings"]=ratings

# %%
pant["price"]=price

# %%
pant["discount"]=discount

# %%
pant
# Out:
#                                             pant name       ratings    price  \
# 0   \n                                        Gree...  [\n, [], \n]  [₹2299]
# 1   \n                                        Grey...  [\n, [], \n]  [₹2449]
# 2   \n                                        Blue...  [\n, [], \n]  [₹2799]
# 3   \n                                        Blac...  [\n, [], \n]  [₹2099]
# 4   \n                                        Blue...  [\n, [], \n]  [₹2299]
# 5   \n                                        Gree...  [\n, [], \n]  [₹2099]
# 6   \n                                        Midn...  [\n, [], \n]  [₹2099]
# 7   \n                                        Blac...  [\n, [], \n]  [₹2099]
# 8   \n                                        Ligh...  [\n, [], \n]  [₹2099]
# 9   \n                                        Beav...  [\n, [], \n]  [₹2199]
# 10  \n                                        Blac...  [\n, [], \n]  [₹2099]
# ...

# %%
pant.to_csv("C:\\Users\\aedpu\\OneDrive\\Documents\\jeanspant.csv")
